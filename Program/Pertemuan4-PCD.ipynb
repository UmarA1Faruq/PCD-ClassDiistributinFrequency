# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# URL gambar
url = "https://akcdn.detik.net.id/community/media/visual/2024/06/19/cristiano-ronaldo-1.jpeg?w=600&q=90"

# Ambil gambar dari URL
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Tampilkan gambar
plt.imshow(img)
plt.axis('off')  # Mematikan axis
plt.show()

# %%
# Mengonversi gambar menjadi grayscale
img_gray = img.convert('L')

# Menampilkan gambar grayscale
plt.imshow(img_gray, cmap='gray')
plt.axis('off')
plt.show()

# %%
# Mengonversi gambar menjadi array NumPy
import numpy as np

img_np = np.array(img)

# Memisahkan masing-masing channel warna
red_channel = img_np[:, :, 0]  # Kanal merah
green_channel = img_np[:, :, 1]  # Kanal hijau
blue_channel = img_np[:, :, 2]  # Kanal biru

# Menampilkan setiap saluran warna
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

axs[0].imshow(red_channel, cmap='Reds')
axs[0].set_title('Red Channel')
axs[0].axis('off')

axs[1].imshow(green_channel, cmap='Greens')
axs[1].set_title('Green Channel')
axs[1].axis('off')

axs[2].imshow(blue_channel, cmap='Blues')
axs[2].set_title('Blue Channel')
axs[2].axis('off')

plt.show()

# %%
# Mengonversi gambar grayscale menjadi array NumPy
img_gray_np = np.array(img_gray)

# Melakukan kuantisasi menjadi 16 tingkat keabuan
quantized_gray = (img_gray_np // 16) * 16  # Mengurangi jumlah tingkatan warna

# Menampilkan hasil kuantisasi
plt.imshow(quantized_gray, cmap='gray')
plt.axis('off')
plt.show()

# %%
# Mengonversi gambar PIL ke array NumPy
img_array = np.array(img)

# Menampilkan dimensi dari array
print("Dimensi gambar:", img_array.shape)
# Out:
# Dimensi gambar: (400, 600, 3)
